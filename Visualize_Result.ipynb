# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os, sys

# %%
def show_images(images, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# %%
saveDir = './Result'
filelist = os.listdir(saveDir)
imglst = []
name = []
filelist.sort()

for file in filelist:    
    img = cv2.imread(saveDir+'/'+file)    
    imglst.append(img*255)
    name.append(file)
    print(file,': ',set(img.flatten()))
    if len(imglst) == 4 :
        show_images(imglst,titles=name)
        imglst = []
        name = []
# Out:
# step0_fuse_channel_background.png :  {0}
# step0_fuse_channel_foreground.png :  {0}
# step0_input_image_channel_background.png :  {0, 1}
# step0_input_image_channel_foreground.png :  {0, 1}
# step1_fuse_channel_background.png :  {0}
# step1_fuse_channel_foreground.png :  {0}
# step1_input_image_channel_background.png :  {0, 1}
# step1_input_image_channel_foreground.png :  {0, 1}
# step2_fuse_channel_background.png :  {0}
# step2_fuse_channel_foreground.png :  {0}
# step2_input_image_channel_background.png :  {0, 1}
# step2_input_image_channel_foreground.png :  {0, 1}
# step3_fuse_channel_background.png :  {0}
# step3_fuse_channel_foreground.png :  {0}
# step3_input_image_channel_background.png :  {0, 1}
# step3_input_image_channel_foreground.png :  {0, 1}
# step4_fuse_channel_background.png :  {0}
# step4_fuse_channel_foreground.png :  {0}
# step4_input_image_channel_background.png :  {0, 1}
# step4_input_image_channel_foreground.png :  {0, 1}
# step5_fuse_channel_background.png :  {0}
# step5_fuse_channel_foreground.png :  {0}
# step5_input_image_channel_background.png :  {0, 1}
# step5_input_image_channel_foreground.png :  {0, 1}
